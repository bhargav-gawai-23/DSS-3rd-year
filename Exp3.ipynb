# %%
# Exp No. 3

# %%
# Aim: To calculate mearures of central tendancy

# %%
# Name: Bhargav V. Gawai
# Roll No.: 16
# Sec: C
# Subject: ET1
# Date: 01/08/25

# %%
age=(22,21,20,22,20,23,22,21,20,20,20,23,21,21,22,23)

# %%
age
# Out:
# (22, 21, 20, 22, 20, 23, 22, 21, 20, 20, 20, 23, 21, 21, 22, 23)

# %%
print(age)
# Out:
# (22, 21, 20, 22, 20, 23, 22, 21, 20, 20, 20, 23, 21, 21, 22, 23)

# %%
import statistics as stats

# %%
a=stats.mean(age)

# %%
a
# Out:
# 21.3125

# %%
b=stats.median(age)

# %%
b
# Out:
# 21.0

# %%
c=stats.mode(age)

# %%
c
# Out:
# 20

# %%
import numpy as np
x=np.array([2,6,5,8,7,8,5,2,6,8,1,2,5,2,5,4,5,1])

# %%
x
# Out:
# array([2, 6, 5, 8, 7, 8, 5, 2, 6, 8, 1, 2, 5, 2, 5, 4, 5, 1])

# %%
print(np.mean(x))
# Out:
# 4.555555555555555

# %%
print(np.mean(x))
# Out:
# 4.555555555555555

# %%
print(np.median(x))
# Out:
# 5.0

# %%
print(np.mode(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(np.mode(x))
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(5), count=np.int64(5))

# %%
print(np.std(x))
# Out:
# 2.3386183533165767

# %%
print(np.var(x))
# Out:
# 5.469135802469136
